# %%
import lasio
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def log_plot(logs):
    logs = logs.sort_values(by='DEPTH')
    top = logs.DEPTH.min()
    bot = logs.DEPTH.max()
    
    f, ax = plt.subplots(nrows=1, ncols=4, figsize=(12,8))
    
    ax[0].plot(logs.GR, logs.DEPTH, color='black')
    ax[1].plot(logs.NPHI, logs.DEPTH, color='blue')
    ax[2].plot(logs.RHOB, logs.DEPTH, color='c')
    ax[3].plot(logs.RT, logs.DEPTH, color='m')
    
    for i in range(len(ax)):
        ax[i].set_ylim(top,bot)
        ax[i].invert_yaxis()
        ax[i].grid()
        
    ax[0].set_xlabel("DT (us/ft)")
    ax[0].set_xlim(logs.DT.min(),logs.DT.max())
    ax[0].set_ylabel("Depth(ft)")
    ax[1].set_xlabel("GR (API)")
    ax[1].set_xlim(0, 200)
    ax[2].set_xlabel("NPHI (v/v)")
    ax[2].set_xlim(logs.NPHI.min(),logs.NPHI.max())
    ax[3].set_xlabel("RHOB (g/cm3)")
    ax[3].set_xlim(logs.RHOB.min(),logs.RHOB.max())
    ax[4].set_xlabel("RT (ohm.m)")
    ax[4].set_xlim(-2,logs.RT.max())
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]);
    ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[4].set_yticklabels([]) 
    
    f.suptitle('Well: 15-9-F-15', fontsize=14,y=0.94)

# %%
las = lasio.read(r'WLC_PETRO_COMPUTED_INPUT_1.LAS')
df = las.df()
df.head()
# Out:
#        ABDCQF01  ABDCQF02  ABDCQF03  ABDCQF04    BS  CALI  DRHO  GR  NBGRCFM  \
# DEPTH
# 145.9       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN      NaN
# 146.0       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN      NaN
# 146.1       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN      NaN
# 146.2       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN      NaN
# 146.3       NaN       NaN       NaN       NaN  36.0   NaN   NaN NaN      NaN
#
#        NPHI  PEF  RACEHM  RACELM  RD  RHOB  RM  ROP  RPCEHM  RPCELM  RT
# DEPTH
# 145.9   NaN  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.0   NaN  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.1   NaN  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.2   NaN  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN
# 146.3   NaN  NaN     NaN     NaN NaN   NaN NaN  NaN     NaN     NaN NaN

# %%
df.isna().sum()
# Out:
# ABDCQF01    31055
# ABDCQF02    31055
# ABDCQF03    31055
# ABDCQF04    31055
# BS              0
# CALI        31733
# DRHO        31727
# GR            745
# NBGRCFM     18333
# NPHI        31825
# PEF         31799
# RACEHM      12517
# RACELM      12517
# RD          12809
# RHOB        31799
# RM          12694
# ROP           713
# RPCEHM      12517
# RPCELM      12632
# RT          12706
# dtype: int64

# %%
df.shape
# Out:
# (45391, 20)

# %%
df['DEPTH'] = df.index
df = df.reset_index(drop=True)
df.reset_index(drop=True, inplace=True)

# %%
plt.plot(df['DEPTH'], np.log(df['RT']))

# %%
plt.plot(df['DEPTH'], df['RT'])

# %%
df1 = pd.DataFrame()
df1['GR'] = df['GR']
df1['NPHI'] = df['NPHI']
df1['RHOB'] = df['RHOB']
df1['RT'] = df['RT']
df1['DEPTH'] = df['DEPTH']

# %%
g = sns.PairGrid(df1)
g.map(plt.scatter)

# %%
df1['RT'] = np.log(df1['RT'])
log_plot(df1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-a25a09c7742f> in <module>()
#       1 df1['RT'] = np.log(df1['RT'])
# ----> 2 log_plot(df1)
#
# <ipython-input-2-fe8325c80dca> in log_plot(logs)
#      17
#      18     ax[0].set_xlabel("DT (us/ft)")
# ---> 19     ax[0].set_xlim(logs.DT.min(),logs.DT.max())
#      20     ax[0].set_ylabel("Depth(ft)")
#      21     ax[1].set_xlabel("GR (API)")
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'DT'

# %%
las.header
# Out:
# {'Version': [HeaderItem(mnemonic=VERS, unit=, value=2.0, descr=CWLS log ASCII Standard Ve...),
#   HeaderItem(mnemonic=WRAP, unit=, value=NO, descr=One line per depth step)],
#  'Well': [HeaderItem(mnemonic=STRT, unit=M, value=145.9, descr=START),
#   HeaderItem(mnemonic=STOP, unit=M, value=4684.9, descr=STOP),
#   HeaderItem(mnemonic=STEP, unit=M, value=0.1, descr=STEP),
#   HeaderItem(mnemonic=NULL, unit=, value=-999.25, descr=NULL VALUE),
#   HeaderItem(mnemonic=COMP, unit=, value=STATOIL PETROLEUM AS, descr=Company),
#   HeaderItem(mnemonic=WELL, unit=, value=15/9-F-15 D, descr=Well),
#   HeaderItem(mnemonic=FLD, unit=, value=VOLVE, descr=Field),
#   HeaderItem(mnemonic=LOC, unit=, value=, descr=Location),
#   HeaderItem(mnemonic=PROV, unit=, value=, descr=Province),
#   HeaderItem(mnemonic=CNTY, unit=, value=MAERSK INSPIRER, descr=County),
#   HeaderItem(mnemonic=STATE, unit=, value=, descr=State),
#   HeaderItem(mnemonic=CTRY, unit=, value=NORWAY, descr=Country),
#   HeaderItem(mnemonic=DATE, unit=, value=, descr=Log Date),
#   HeaderItem(mnemonic=SRVC, unit=, value=, descr=Service Company),
#   HeaderItem(mnemonic=UWI, unit=, value=, descr=Unique Well Identifier),
#   HeaderItem(mnemonic=API, unit=, value=, descr=API Number),
#   HeaderItem(mnemonic=LATI, unit=, value=058 26' 29.706" N    DMS, descr=Latitude),
#   HeaderItem(mnemonic=LONG, unit=, value=001 53' 15.149" E    DMS, descr=Longt...),
#   HeaderItem(mnemonic=PD, unit=, value=MSL, descr=Permanent Datum),
#   HeaderItem(mnemonic=EDF, unit=M, value=54.9, descr=Elevations D.F.),
#   HeaderItem(mnemonic=EGL, unit=M, value=-91.0, descr=Elevations G.L.),
#   HeaderItem(mnemonic=ELZ, unit=M, value=54.9, descr=Elev. Log Zero),
#   HeaderItem(mnemonic=LMF, unit=, value=DF, descr=Log Measured From),
#   HeaderItem(mnemonic=MP, unit=, value=DF, descr=Drill Measured From)],
#  'Curves': [CurveItem(mnemonic=DEPTH, unit=M, value=00 001 00 00, descr=0  Depth, original_mnemonic=DEPTH, data.shape=(45391,)),
#   CurveItem(mnemonic=ABDCQF01, unit=g/cm3, value=00 000 00 00:   1  ABDCQF01:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=ABDCQF01, data.shape=(45391,)),
#   CurveItem(mnemonic=ABDCQF02, unit=g/cm3, value=00 000 00 00:   2  ABDCQF02:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=ABDCQF02, data.shape=(45391,)),
#   CurveItem(mnemonic=ABDCQF03, unit=g/cm3, value=00 000 00 00:   3  ABDCQF03:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=ABDCQF03, data.shape=(45391,)),
#   CurveItem(mnemonic=ABDCQF04, unit=g/cm3, value=00 000 00 00:   4  ABDCQF04:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=ABDCQF04, data.shape=(45391,)),
#   CurveItem(mnemonic=BS, unit=inches, value=00 000 00 00:   5  BS:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=BS, data.shape=(45391,)),
#   CurveItem(mnemonic=CALI, unit=inches, value=70 280 00 01:   6  CALI:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=CALI, data.shape=(45391,)),
#   CurveItem(mnemonic=DRHO, unit=g/cm3, value=45 356 01 01:   7  DRHO:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=DRHO, data.shape=(45391,)),
#   CurveItem(mnemonic=GR, unit=API, value=30 150 01 01:   8  GR:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=GR, data.shape=(45391,)),
#   CurveItem(mnemonic=NBGRCFM, unit=API, value=00 000 00 00:   9  NBGRCFM:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=NBGRCFM, data.shape=(45391,)),
#   CurveItem(mnemonic=NPHI, unit=v/v, value=42 890 01 01:  10  NPHI:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=NPHI, data.shape=(45391,)),
#   CurveItem(mnemonic=PEF, unit=b/elec, value=45 358 01 01:  11  PEF:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=PEF, data.shape=(45391,)),
#   CurveItem(mnemonic=RACEHM, unit=ohm.m, value=95 220 00 01:  12  RACEHM:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RACEHM, data.shape=(45391,)),
#   CurveItem(mnemonic=RACELM, unit=ohm.m, value=00 524 01 00:  13  RACELM:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RACELM, data.shape=(45391,)),
#   CurveItem(mnemonic=RD, unit=ohm.m, value=00 000 00 00:  14  RD:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RD, data.shape=(45391,)),
#   CurveItem(mnemonic=RHOB, unit=g/cm3, value=45 350 01 01:  15  RHOB:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RHOB, data.shape=(45391,)),
#   CurveItem(mnemonic=RM, unit=ohm.m, value=00 000 00 00:  16  RM:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RM, data.shape=(45391,)),
#   CurveItem(mnemonic=ROP, unit=m/hr, value=00 000 00 00:  17  ROP:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=ROP, data.shape=(45391,)),
#   CurveItem(mnemonic=RPCEHM, unit=ohm.m, value=00 000 00 00:  18  RPCEHM:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RPCEHM, data.shape=(45391,)),
#   CurveItem(mnemonic=RPCELM, unit=ohm.m, value=00 000 00 00:  19  RPCELM:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RPCELM, data.shape=(45391,)),
#   CurveItem(mnemonic=RT, unit=ohm.m, value=00 000 00 00:  20  RT:COMPOSITE:rC:NONE, descr=v1, original_mnemonic=RT, data.shape=(45391,))],
#  'Parameter': [HeaderItem(mnemonic=RUN, unit=, value=., descr=Run Number)],
#  'Other': 'PETROPHYSICAL INTERPRETATION: INPUT'}

# %%
df1 = df1.dropna()
df1.to_csv('edited.csv', index=False)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lasio
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
import sklearn.model_selection as ms
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb
import lightgbm as lgb
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# C:\Users\hp\Anaconda3\lib\site-packages\distributed\utils.py:134: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [WinError 10065] A socket operation was attempted to an unreachable host
#   % (host, default, e), RuntimeWarning)

# %%
def log_plot(logs):
    logs = logs.sort_values(by='DEPTH')
    top = logs.DEPTH.min()
    bot = logs.DEPTH.max()
    
    f, ax = plt.subplots(nrows=1, ncols=5, figsize=(12,8))
    ax[0].plot(logs.DT, logs.DEPTH, color='red')
    ax[1].plot(logs.GR, logs.DEPTH, color='black')
    ax[2].plot(logs.NPHI, logs.DEPTH, color='blue')
    ax[3].plot(logs.RHOB, logs.DEPTH, color='c')
    ax[4].plot(logs.RT, logs.DEPTH, color='m')
    
    for i in range(len(ax)):
        ax[i].set_ylim(top,bot)
        ax[i].invert_yaxis()
        ax[i].grid()
        
    ax[0].set_xlabel("DT (us/ft)")
    ax[0].set_xlim(30, 150)
    ax[0].set_ylabel("Depth(ft)")
    ax[1].set_xlabel("GR (API)")
    ax[1].set_xlim(logs.GR.min(), 200)
    ax[2].set_xlabel("NPHI (v/v)")
    ax[2].set_xlim(logs.NPHI.min(),logs.NPHI.max())
    ax[3].set_xlabel("RHOB (g/cm3)")
    ax[3].set_xlim(logs.RHOB.min(),logs.RHOB.max())
    ax[4].set_xlabel("RT (ohm.m)")
    ax[4].set_xlim(-2,logs.RT.max())
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]);
    ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[4].set_yticklabels([]) 
    
    f.suptitle('Well: 15-9-F-11', fontsize=14,y=0.94)

# %%
def log_plot1(logs):
    logs = logs.sort_values(by='DEPTH')
    top = logs.DEPTH.min()
    bot = logs.DEPTH.max()
    
    f, ax = plt.subplots(nrows=1, ncols=5, figsize=(12,8))
    ax[0].plot(logs.DT, logs.DEPTH, color='red')
    ax[1].plot(logs.GR, logs.DEPTH, color='black')
    ax[2].plot(logs.NPHI, logs.DEPTH, color='blue')
    ax[3].plot(logs.RHOB, logs.DEPTH, color='c')
    ax[4].plot(logs.RT, logs.DEPTH, color='m')
    
    for i in range(len(ax)):
        ax[i].set_ylim(top,bot)
        ax[i].invert_yaxis()
        ax[i].grid()
        
    ax[0].set_xlabel("DT (us/ft)")
    ax[0].set_xlim(logs.DT.min(), logs.DT.max())
    ax[0].set_ylabel("Depth(ft)")
    ax[1].set_xlabel("GR (API)")
    ax[1].set_xlim(logs.GR.min(), logs.GR.max())
    ax[2].set_xlabel("NPHI (v/v)")
    ax[2].set_xlim(logs.NPHI.min(),logs.NPHI.max())
    ax[3].set_xlabel("RHOB (g/cm3)")
    ax[3].set_xlim(logs.RHOB.min(),logs.RHOB.max())
    ax[4].set_xlabel("RT (ohm.m)")
    ax[4].set_xlim(-2,logs.RT.max())
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]);
    ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[4].set_yticklabels([]) 
    
    f.suptitle('Well: 15-9-F-11', fontsize=14,y=0.94)

# %%
df = pd.read_csv('F12.csv')

# %%
df['RT'] = np.log(df['RT'])
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
log_plot(df)

# %%
df1 = df.dropna()
log_plot(df1)

# %%
test = pd.read_csv('edited.csv')
test['RT'] = np.log(test['RT'])
log_plot(test)

# %%
test = test.dropna()
log_plot(test)

# %%
test.to_csv('edited1.csv', index=False)

# %%
labels = np.array(df1['DT'])
df1 = df1.drop(['DEPTH', 'DT'], axis=1)
features = np.array(df1)

## Randomly sample cases to create independent training and test data
np.random.seed(9988)
indx = range(features.shape[0])
indx = ms.train_test_split(indx, test_size = 0.4)
x_train = features[indx[0],:]
y_train = np.ravel(labels[indx[0]])
x_test = features[indx[1],:]
y_test = np.ravel(labels[indx[1]])

## Randomly sample cases to create independent training and test data
np.random.seed(9988)
indx1 = range(x_test.shape[0])
indx1 = ms.train_test_split(indx1, test_size = 0.5)
x_test1 = x_test[indx1[0],:]
y_test1 = np.ravel(y_test[indx1[0]])
x_test2 = x_test[indx1[1],:]
y_test2 = np.ravel(y_test[indx1[1]])

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (24431, 4)
# (24431,)
# (16288, 4)
# (16288,)

# %%
print(x_test1.shape)
print(y_test1.shape)
print(x_test2.shape)
print(y_test2.shape)
# Out:
# (8144, 4)
# (8144,)
# (8144, 4)
# (8144,)

# %%
df1.shape
# Out:
# (40719, 4)

# %%
rf = RandomForestRegressor(n_estimators=600, max_depth=15, max_features='auto',
                            min_samples_leaf=1, min_samples_split=2, random_state=0)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=15,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
xg_dt = xgb.XGBRegressor(boosting_type='gbtree', learning_rate=0.01, n_estimators=4000, max_depth=15, base_score=0.7)
eval_set = [(x_test1, y_test1)]
xg_dt.fit(x_train, y_train, eval_set=eval_set, early_stopping_rounds=200)
# Out:
# [0]	validation_0-rmse:76.46152
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1]	validation_0-rmse:75.69960
# [2]	validation_0-rmse:74.94565
# [3]	validation_0-rmse:74.19904
# [4]	validation_0-rmse:73.46004
# [5]	validation_0-rmse:72.72845
# [6]	validation_0-rmse:72.00407
# [7]	validation_0-rmse:71.28704
# [8]	validation_0-rmse:70.57707
# [9]	validation_0-rmse:69.87435
# [10]	validation_0-rmse:69.17871
# [11]	validation_0-rmse:68.49006
# [12]	validation_0-rmse:67.80819
# [13]	validation_0-rmse:67.13320
# [14]	validation_0-rmse:66.46494
# [15]	validation_0-rmse:65.80341
# [16]	validation_0-rmse:65.14848
# [17]	validation_0-rmse:64.50020
# [18]	validation_0-rmse:63.85839
# [19]	validation_0-rmse:63.22292
# [20]	validation_0-rmse:62.59394
# [21]	validation_0-rmse:61.97109
# [22]	validation_0-rmse:61.35464
# [23]	validation_0-rmse:60.74453
# [24]	validation_0-rmse:60.14014
# [25]	validation_0-rmse:59.54206
# [26]	validation_0-rmse:58.94946
# [27]	validation_0-rmse:58.36326
# [28]	validation_0-rmse:57.78256
# [29]	validation_0-rmse:57.20799
# [30]	validation_0-rmse:56.63889
# [31]	validation_0-rmse:56.07576
# [32]	validation_0-rmse:55.51794
# [33]	validation_0-rmse:54.96608
# [34]	validation_0-rmse:54.41958
# [35]	validation_0-rmse:53.87924
# [36]	validation_0-rmse:53.34355
# [37]	validation_0-rmse:52.81398
# [38]	validation_0-rmse:52.28917
# [39]	validation_0-rmse:51.77005
# [40]	validation_0-rmse:51.25557
# [41]	validation_0-rmse:50.74685
# [42]	validation_0-rmse:50.24323
# [43]	validation_0-rmse:49.74419
# [44]	validation_0-rmse:49.25063
# [45]	validation_0-rmse:48.76181
# [46]	validation_0-rmse:48.27800
# [47]	validation_0-rmse:47.79918
# [48]	validation_0-rmse:47.32484
# [49]	validation_0-rmse:46.85567
# [50]	validation_0-rmse:46.39081
# [51]	validation_0-rmse:45.93083
# [52]	validation_0-rmse:45.47567
# [53]	validation_0-rmse:45.02457
# [54]	validation_0-rmse:44.57816
# [55]	validation_0-rmse:44.13601
# [56]	validation_0-rmse:43.69881
# [57]	validation_0-rmse:43.26542
# [58]	validation_0-rmse:42.83700
# [59]	validation_0-rmse:42.41244
# [60]	validation_0-rmse:41.99226
# [61]	validation_0-rmse:41.57635
# [62]	validation_0-rmse:41.16440
# [63]	validation_0-rmse:40.75659
# [64]	validation_0-rmse:40.35305
# [65]	validation_0-rmse:39.95348
# [66]	validation_0-rmse:39.55804
# [67]	validation_0-rmse:39.16647
# [68]	validation_0-rmse:38.77894
# [69]	validation_0-rmse:38.39525
# [70]	validation_0-rmse:38.01566
# [71]	validation_0-rmse:37.63959
# [72]	validation_0-rmse:37.26718
# [73]	validation_0-rmse:36.89887
# [74]	validation_0-rmse:36.53400
# [75]	validation_0-rmse:36.17285
# [76]	validation_0-rmse:35.81541
# [77]	validation_0-rmse:35.46154
# [78]	validation_0-rmse:35.11120
# [79]	validation_0-rmse:34.76444
# [80]	validation_0-rmse:34.42143
# [81]	validation_0-rmse:34.08149
# [82]	validation_0-rmse:33.74519
# [83]	validation_0-rmse:33.41200
# [84]	validation_0-rmse:33.08249
# [85]	validation_0-rmse:32.75590
# [86]	validation_0-rmse:32.43317
# [87]	validation_0-rmse:32.11318
# [88]	validation_0-rmse:31.79704
# [89]	validation_0-rmse:31.48395
# [90]	validation_0-rmse:31.17403
# [91]	validation_0-rmse:30.86719
# [92]	validation_0-rmse:30.56314
# [93]	validation_0-rmse:30.26254
# [94]	validation_0-rmse:29.96496
# [95]	validation_0-rmse:29.66994
# [96]	validation_0-rmse:29.37832
# [97]	validation_0-rmse:29.08969
# [98]	validation_0-rmse:28.80410
# [99]	validation_0-rmse:28.52131
# [100]	validation_0-rmse:28.24103
# [101]	validation_0-rmse:27.96402
# [102]	validation_0-rmse:27.68985
# [103]	validation_0-rmse:27.41798
# [104]	validation_0-rmse:27.14944
# [105]	validation_0-rmse:26.88307
# [106]	validation_0-rmse:26.61947
# [107]	validation_0-rmse:26.35886
# [108]	validation_0-rmse:26.10036
# [109]	validation_0-rmse:25.84504
# [110]	validation_0-rmse:25.59169
# [111]	validation_0-rmse:25.34158
# [112]	validation_0-rmse:25.09405
# [113]	validation_0-rmse:24.84843
# [114]	validation_0-rmse:24.60567
# [115]	validation_0-rmse:24.36497
# [116]	validation_0-rmse:24.12726
# [117]	validation_0-rmse:23.89156
# [118]	validation_0-rmse:23.65873
# [119]	validation_0-rmse:23.42764
# [120]	validation_0-rmse:23.19964
# [121]	validation_0-rmse:22.97340
# [122]	validation_0-rmse:22.74978
# [123]	validation_0-rmse:22.52851
# [124]	validation_0-rmse:22.30954
# [125]	validation_0-rmse:22.09223
# [126]	validation_0-rmse:21.87759
# [127]	validation_0-rmse:21.66476
# [128]	validation_0-rmse:21.45471
# [129]	validation_0-rmse:21.24640
# [130]	validation_0-rmse:21.04057
# [131]	validation_0-rmse:20.83645
# [132]	validation_0-rmse:20.63475
# [133]	validation_0-rmse:20.43511
# [134]	validation_0-rmse:20.23729
# [135]	validation_0-rmse:20.04164
# [136]	validation_0-rmse:19.84781
# [137]	validation_0-rmse:19.65639
# [138]	validation_0-rmse:19.46661
# [139]	validation_0-rmse:19.27879
# [140]	validation_0-rmse:19.09306
# [141]	validation_0-rmse:18.90906
# [142]	validation_0-rmse:18.72707
# [143]	validation_0-rmse:18.54688
# [144]	validation_0-rmse:18.36833
# [145]	validation_0-rmse:18.19167
# [146]	validation_0-rmse:18.01700
# [147]	validation_0-rmse:17.84393
# [148]	validation_0-rmse:17.67308
# [149]	validation_0-rmse:17.50361
# [150]	validation_0-rmse:17.33574
# [151]	validation_0-rmse:17.16996
# [152]	validation_0-rmse:17.00564
# [153]	validation_0-rmse:16.84323
# [154]	validation_0-rmse:16.68273
# [155]	validation_0-rmse:16.52347
# [156]	validation_0-rmse:16.36606
# [157]	validation_0-rmse:16.21028
# [158]	validation_0-rmse:16.05639
# [159]	validation_0-rmse:15.90358
# [160]	validation_0-rmse:15.75282
# [161]	validation_0-rmse:15.60371
# [162]	validation_0-rmse:15.45610
# [163]	validation_0-rmse:15.30959
# [164]	validation_0-rmse:15.16513
# [165]	validation_0-rmse:15.02245
# [166]	validation_0-rmse:14.88115
# [167]	validation_0-rmse:14.74078
# [168]	validation_0-rmse:14.60244
# [169]	validation_0-rmse:14.46487
# [170]	validation_0-rmse:14.32926
# [171]	validation_0-rmse:14.19529
# [172]	validation_0-rmse:14.06211
# [173]	validation_0-rmse:13.93019
# [174]	validation_0-rmse:13.80026
# [175]	validation_0-rmse:13.67139
# [176]	validation_0-rmse:13.54402
# [177]	validation_0-rmse:13.41796
# [178]	validation_0-rmse:13.29361
# [179]	validation_0-rmse:13.17038
# [180]	validation_0-rmse:13.04834
# [181]	validation_0-rmse:12.92722
# [182]	validation_0-rmse:12.80802
# [183]	validation_0-rmse:12.68971
# [184]	validation_0-rmse:12.57278
# [185]	validation_0-rmse:12.45689
# [186]	validation_0-rmse:12.34232
# [187]	validation_0-rmse:12.22898
# [188]	validation_0-rmse:12.11684
# [189]	validation_0-rmse:12.00603
# [190]	validation_0-rmse:11.89650
# [191]	validation_0-rmse:11.78798
# [192]	validation_0-rmse:11.68077
# [193]	validation_0-rmse:11.57489
# [194]	validation_0-rmse:11.46958
# [195]	validation_0-rmse:11.36547
# [196]	validation_0-rmse:11.26263
# [197]	validation_0-rmse:11.16080
# [198]	validation_0-rmse:11.06023
# [199]	validation_0-rmse:10.96060
# [200]	validation_0-rmse:10.86241
# [201]	validation_0-rmse:10.76525
# [202]	validation_0-rmse:10.66889
# [203]	validation_0-rmse:10.57392
# [204]	validation_0-rmse:10.47996
# [205]	validation_0-rmse:10.38713
# [206]	validation_0-rmse:10.29485
# [207]	validation_0-rmse:10.20347
# [208]	validation_0-rmse:10.11309
# [209]	validation_0-rmse:10.02401
# [210]	validation_0-rmse:9.93575
# [211]	validation_0-rmse:9.84881
# [212]	validation_0-rmse:9.76241
# [213]	validation_0-rmse:9.67692
# [214]	validation_0-rmse:9.59253
# [215]	validation_0-rmse:9.50907
# [216]	validation_0-rmse:9.42685
# [217]	validation_0-rmse:9.34519
# [218]	validation_0-rmse:9.26474
# [219]	validation_0-rmse:9.18497
# [220]	validation_0-rmse:9.10631
# [221]	validation_0-rmse:9.02840
# [222]	validation_0-rmse:8.95155
# [223]	validation_0-rmse:8.87545
# [224]	validation_0-rmse:8.80036
# [225]	validation_0-rmse:8.72610
# [226]	validation_0-rmse:8.65284
# [227]	validation_0-rmse:8.58054
# [228]	validation_0-rmse:8.50875
# [229]	validation_0-rmse:8.43808
# [230]	validation_0-rmse:8.36823
# [231]	validation_0-rmse:8.29896
# [232]	validation_0-rmse:8.23051
# [233]	validation_0-rmse:8.16280
# [234]	validation_0-rmse:8.09591
# [235]	validation_0-rmse:8.02986
# [236]	validation_0-rmse:7.96471
# [237]	validation_0-rmse:7.90029
# [238]	validation_0-rmse:7.83660
# [239]	validation_0-rmse:7.77347
# [240]	validation_0-rmse:7.71104
# [241]	validation_0-rmse:7.64965
# [242]	validation_0-rmse:7.58881
# [243]	validation_0-rmse:7.52837
# [244]	validation_0-rmse:7.46878
# [245]	validation_0-rmse:7.40998
# [246]	validation_0-rmse:7.35202
# [247]	validation_0-rmse:7.29456
# [248]	validation_0-rmse:7.23783
# [249]	validation_0-rmse:7.18152
# [250]	validation_0-rmse:7.12615
# [251]	validation_0-rmse:7.07146
# [252]	validation_0-rmse:7.01753
# [253]	validation_0-rmse:6.96404
# [254]	validation_0-rmse:6.91147
# [255]	validation_0-rmse:6.85931
# [256]	validation_0-rmse:6.80772
# [257]	validation_0-rmse:6.75691
# [258]	validation_0-rmse:6.70660
# [259]	validation_0-rmse:6.65715
# [260]	validation_0-rmse:6.60814
# [261]	validation_0-rmse:6.55971
# [262]	validation_0-rmse:6.51194
# [263]	validation_0-rmse:6.46488
# [264]	validation_0-rmse:6.41835
# [265]	validation_0-rmse:6.37226
# [266]	validation_0-rmse:6.32689
# [267]	validation_0-rmse:6.28187
# [268]	validation_0-rmse:6.23778
# [269]	validation_0-rmse:6.19395
# [270]	validation_0-rmse:6.15091
# [271]	validation_0-rmse:6.10855
# [272]	validation_0-rmse:6.06659
# [273]	validation_0-rmse:6.02522
# [274]	validation_0-rmse:5.98438
# [275]	validation_0-rmse:5.94382
# [276]	validation_0-rmse:5.90412
# [277]	validation_0-rmse:5.86519
# [278]	validation_0-rmse:5.82618
# [279]	validation_0-rmse:5.78819
# [280]	validation_0-rmse:5.75054
# [281]	validation_0-rmse:5.71327
# [282]	validation_0-rmse:5.67622
# [283]	validation_0-rmse:5.63979
# [284]	validation_0-rmse:5.60387
# [285]	validation_0-rmse:5.56841
# [286]	validation_0-rmse:5.53319
# [287]	validation_0-rmse:5.49833
# [288]	validation_0-rmse:5.46414
# [289]	validation_0-rmse:5.43028
# [290]	validation_0-rmse:5.39699
# [291]	validation_0-rmse:5.36430
# [292]	validation_0-rmse:5.33193
# [293]	validation_0-rmse:5.30014
# [294]	validation_0-rmse:5.26836
# [295]	validation_0-rmse:5.23758
# [296]	validation_0-rmse:5.20710
# [297]	validation_0-rmse:5.17653
# [298]	validation_0-rmse:5.14698
# [299]	validation_0-rmse:5.11750
# [300]	validation_0-rmse:5.08831
# [301]	validation_0-rmse:5.05971
# [302]	validation_0-rmse:5.03147
# [303]	validation_0-rmse:5.00365
# [304]	validation_0-rmse:4.97633
# [305]	validation_0-rmse:4.94925
# [306]	validation_0-rmse:4.92250
# [307]	validation_0-rmse:4.89641
# [308]	validation_0-rmse:4.87074
# [309]	validation_0-rmse:4.84495
# [310]	validation_0-rmse:4.82017
# [311]	validation_0-rmse:4.79606
# [312]	validation_0-rmse:4.77233
# [313]	validation_0-rmse:4.74822
# [314]	validation_0-rmse:4.72432
# [315]	validation_0-rmse:4.70087
# [316]	validation_0-rmse:4.67783
# [317]	validation_0-rmse:4.65543
# [318]	validation_0-rmse:4.63305
# [319]	validation_0-rmse:4.61111
# [320]	validation_0-rmse:4.58974
# [321]	validation_0-rmse:4.56876
# [322]	validation_0-rmse:4.54780
# [323]	validation_0-rmse:4.52660
# [324]	validation_0-rmse:4.50623
# [325]	validation_0-rmse:4.48652
# [326]	validation_0-rmse:4.46658
# [327]	validation_0-rmse:4.44689
# [328]	validation_0-rmse:4.42762
# [329]	validation_0-rmse:4.40898
# [330]	validation_0-rmse:4.39025
# [331]	validation_0-rmse:4.37194
# [332]	validation_0-rmse:4.35384
# [333]	validation_0-rmse:4.33613
# [334]	validation_0-rmse:4.31860
# [335]	validation_0-rmse:4.30133
# [336]	validation_0-rmse:4.28446
# [337]	validation_0-rmse:4.26774
# [338]	validation_0-rmse:4.25118
# [339]	validation_0-rmse:4.23503
# [340]	validation_0-rmse:4.21902
# [341]	validation_0-rmse:4.20286
# [342]	validation_0-rmse:4.18696
# [343]	validation_0-rmse:4.17183
# [344]	validation_0-rmse:4.15656
# [345]	validation_0-rmse:4.14179
random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#        tree_method=None, validate_parameters=False, verbosity=None)

# %%
pred_xg = xg_dt.predict(x_test2)
print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(pred_xg, y_test2) ** 0.5}')
print(f'The R2_score of DT values predicted on the validation data is {r2_score(pred_xg, y_test2) * 100}')

pred_rf = rf.predict(x_test2)
print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(pred_rf, y_test2) ** 0.5}')
print(f'The R2_score of DT values predicted on the validation data is {r2_score(pred_rf, y_test2) * 100}')
# Out:
# The RMSE of DT values predicted on the validation data is 3.2616667553181484
# The R2_score of DT values predicted on the validation data is 94.75206642439323
# The RMSE of DT values predicted on the validation data is 3.2809297242297504
# The R2_score of DT values predicted on the validation data is 94.68663201153244

# %%
test = pd.read_csv('edited.csv')
test = test.dropna()

dt = np.array(test['DT'])
test = test.drop(['DT', 'DEPTH'], axis=1)
test = np.array(test)

# %%
predictions_xg = xg_dt.predict(test)
predictions_rf = rf.predict(test)

# %%
test = pd.read_csv('edited.csv')
test = test.dropna()
dt = np.array(test['DT'])
test['DT'] = predictions_xg
log_plot(test)

# %%
test = pd.read_csv('edited.csv')
test.describe()
# Out:
#                  DT            GR          NPHI          RHOB            RT  \
# count  13077.000000  25895.000000  18063.000000  13951.000000  21274.000000
# mean     106.160387     84.868677      0.346371      2.124767     20.857914
# std       28.132972     35.953262      0.177050      0.229125    254.978691
# min      -68.827796     10.688800      0.028200      1.356800      0.100000
# 25%       78.402496     58.513599      0.210000      1.941450      0.674425
# 50%      114.111999     92.544800      0.332500      2.133400      1.088450
# 75%      131.834197    110.460300      0.485000      2.301850      1.730600
# max      161.014801    179.878204      1.505700      2.939200   5000.000000
#
#               DEPTH
# count  25899.000000
# mean    2213.305200
# std     1139.424947
# min      239.877600
# 25%     1226.591400
# 50%     2213.305200
# 75%     3200.019000
# max     4186.732800

# %%
test = pd.read_csv('edited.csv')
test = test.dropna()
dt = np.array(test['DT'])
test['DT'] = predictions_xg
log_plot(test)

# %%
test.describe()
# Out:
#                  DT            GR          NPHI          RHOB            RT  \
# count  12860.000000  12860.000000  12860.000000  12860.000000  12860.000000
# mean      93.633682     90.155106      0.278832      2.122411     33.496936
# std       16.709959     42.289737      0.142013      0.227564    327.162094
# min       57.809597     12.789500      0.028200      1.356800      0.100000
# 25%       80.247707     49.477076      0.182700      1.938875      0.589850
# 50%       91.255661    106.072700      0.263150      2.121150      0.891750
# 75%      111.532228    126.951624      0.371600      2.297800      2.494900
# max      131.903336    179.878204      1.113800      2.939200   5000.000000
#
#               DEPTH
# count  12860.000000
# mean    2404.319272
# std      604.841370
# min     1368.704400
# 25%     1869.147900
# 50%     2408.301000
# 75%     2919.869700
# max     3442.563600

# %%
test['DT'] = predictions_xg
log_plot(test)

# %%
test.describe()
# Out:
#                  DT            GR          NPHI          RHOB            RT  \
# count  12860.000000  12860.000000  12860.000000  12860.000000  12860.000000
# mean      93.633682     90.155106      0.278832      2.122411     33.496936
# std       16.709959     42.289737      0.142013      0.227564    327.162094
# min       57.809597     12.789500      0.028200      1.356800      0.100000
# 25%       80.247707     49.477076      0.182700      1.938875      0.589850
# 50%       91.255661    106.072700      0.263150      2.121150      0.891750
# 75%      111.532228    126.951624      0.371600      2.297800      2.494900
# max      131.903336    179.878204      1.113800      2.939200   5000.000000
#
#               DEPTH
# count  12860.000000
# mean    2404.319272
# std      604.841370
# min     1368.704400
# 25%     1869.147900
# 50%     2408.301000
# 75%     2919.869700
# max     3442.563600

# %%
print(dt[0:20])
print('')
print(predictions_xg[0:20])
print('')
print(predictions_rf[0:20])
# Out:
# [152.749801 151.107299 153.146392 151.787597 150.264892 149.669998
#  148.460403 145.468902 146.367202 144.778793 148.945404 149.7583
#  151.868103 145.955902 143.287399 142.185897 143.262893 141.159896
#  140.048599 140.773101]
#
# [113.23004  114.187675 114.56573  113.86794  114.64511  114.370995
#  114.439926 114.22749  117.728935 117.94992  114.15714  114.19427
#  115.96262  116.240746 115.58745  115.11141  112.42559  113.61934
#  116.16142  114.96855 ]
#
# [116.26369753 115.91825914 115.62427027 116.23751398 116.35572732
#  116.14956086 116.26165733 116.29803116 115.90213349 115.81845915
#  116.15066572 116.16859118 118.97728219 118.52665102 119.61564378
#  119.33542597 117.64798123 116.50895374 118.8464546  118.5520143 ]

# %%
print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(predictions_xg, dt) ** 0.5}')
print(f'The R2_Score of DT values predicted on the validation data is {r2_score(predictions_xg, dt) * 100}')

print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(predictions_rf, dt) ** 0.5}')
print(f'The R2_Score of DT values predicted on the validation data is {r2_score(predictions_rf, dt) * 100}')
# Out:
# The RMSE of DT values predicted on the validation data is 21.484999417673972
# The R2_Score of DT values predicted on the validation data is -65.3307851971335
# The RMSE of DT values predicted on the validation data is 21.14665069562679
# The R2_Score of DT values predicted on the validation data is -61.47300247346972

# %%
rf.feature_importances_
# Out:
# array([0.03239017, 0.90141451, 0.04334147, 0.02285385])

# %%
xg_dt.feature_importances_
# Out:
# array([0.01364762, 0.9369131 , 0.03439176, 0.01504743], dtype=float32)

# %%
edited = pd.read_csv('11B.csv')

edited = edited.drop(['DEPTH'], axis=1)
edited = np.array(edited)

rf_11b = rf.predict(edited)

edited = pd.read_csv('11B.csv')
edited['DT'] = rf_11b

edited['RT'] = np.log(edited['RT'])
log_plot1(edited)

# %%
edited['RT'] = np.log(edited['RT'])

# %%
edited.to_csv('final_11B.csv', index=False)

# %%
edited = pd.read_csv('15D.csv')

edited = edited.drop(['DEPTH'], axis=1)
edited = np.array(edited)

rf_15D = rf.predict(edited)

edited = pd.read_csv('15D.csv')
edited['DT'] = rf_15D

edited['RT'] = np.log(edited['RT'])
log_plot1(edited)

# %%
scores = cross_val_score(rf, x_train, y_train, cv=5)

# %%
print(scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.95506918 0.94609617 0.94809574 0.94587084 0.94663925]
# Accuracy: 0.95 (+/- 0.01)

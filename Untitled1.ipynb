# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lasio
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
import sklearn.model_selection as ms
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import xgboost as xgb
import lightgbm as lgb
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# C:\Users\hp\Anaconda3\lib\site-packages\distributed\utils.py:134: RuntimeWarning: Couldn't detect a suitable IP address for reaching '8.8.8.8', defaulting to '127.0.0.1': [WinError 10065] A socket operation was attempted to an unreachable host
#   % (host, default, e), RuntimeWarning)

# %%
def log_plot(logs):
    logs = logs.sort_values(by='DEPTH')
    top = logs.DEPTH.min()
    bot = logs.DEPTH.max()
    
    f, ax = plt.subplots(nrows=1, ncols=5, figsize=(12,8))
    ax[0].plot(logs.DT, logs.DEPTH, color='red')
    ax[1].plot(logs.GR, logs.DEPTH, color='black')
    ax[2].plot(logs.NPHI, logs.DEPTH, color='blue')
    ax[3].plot(logs.RHOB, logs.DEPTH, color='c')
    ax[4].plot(logs.RT, logs.DEPTH, color='m')
    
    for i in range(len(ax)):
        ax[i].set_ylim(top,bot)
        ax[i].invert_yaxis()
        ax[i].grid()
        
    ax[0].set_xlabel("DT (us/ft)")
    ax[0].set_xlim(30, 150)
    ax[0].set_ylabel("Depth(ft)")
    ax[1].set_xlabel("GR (API)")
    ax[1].set_xlim(logs.GR.min(), 200)
    ax[2].set_xlabel("NPHI (v/v)")
    ax[2].set_xlim(logs.NPHI.min(),logs.NPHI.max())
    ax[3].set_xlabel("RHOB (g/cm3)")
    ax[3].set_xlim(logs.RHOB.min(),logs.RHOB.max())
    ax[4].set_xlabel("RT (ohm.m)")
    ax[4].set_xlim(-2,logs.RT.max())
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]);
    ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[4].set_yticklabels([]) 
    
    f.suptitle('Well: 15-9-F-11', fontsize=14,y=0.94)

# %%
def log_plot1(logs):
    logs = logs.sort_values(by='DEPTH')
    top = logs.DEPTH.min()
    bot = logs.DEPTH.max()
    
    f, ax = plt.subplots(nrows=1, ncols=5, figsize=(12,8))
    ax[0].plot(logs.DT, logs.DEPTH, color='red')
    ax[1].plot(logs.GR, logs.DEPTH, color='black')
    ax[2].plot(logs.NPHI, logs.DEPTH, color='blue')
    ax[3].plot(logs.RHOB, logs.DEPTH, color='c')
    ax[4].plot(logs.RT, logs.DEPTH, color='m')
    
    for i in range(len(ax)):
        ax[i].set_ylim(top,bot)
        ax[i].invert_yaxis()
        ax[i].grid()
        
    ax[0].set_xlabel("DT (us/ft)")
    ax[0].set_xlim(logs.DT.min(), logs.DT.max())
    ax[0].set_ylabel("Depth(ft)")
    ax[1].set_xlabel("GR (API)")
    ax[1].set_xlim(logs.GR.min(), logs.GR.max())
    ax[2].set_xlabel("NPHI (v/v)")
    ax[2].set_xlim(logs.NPHI.min(),logs.NPHI.max())
    ax[3].set_xlabel("RHOB (g/cm3)")
    ax[3].set_xlim(logs.RHOB.min(),logs.RHOB.max())
    ax[4].set_xlabel("RT (ohm.m)")
    ax[4].set_xlim(-2,logs.RT.max())
    
    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]);
    ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[4].set_yticklabels([]) 
    
    f.suptitle('Well: 15-9-F-11', fontsize=14,y=0.94)

# %%
df = pd.read_csv('11A.csv')

# %%
df['RT'] = np.log(df['RT'])
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
log_plot(df)

# %%
df1 = df.dropna()
log_plot(df1)

# %%
test = pd.read_csv('edited.csv')
log_plot(test)

# %%
test = test.dropna()
log_plot(test)

# %%
labels = np.array(df1['DT'])
df1 = df1.drop(['DEPTH', 'DT'], axis=1)
features = np.array(df1)

## Randomly sample cases to create independent training and test data
np.random.seed(9988)
indx = range(features.shape[0])
indx = ms.train_test_split(indx, test_size = 0.4)
x_train = features[indx[0],:]
y_train = np.ravel(labels[indx[0]])
x_test = features[indx[1],:]
y_test = np.ravel(labels[indx[1]])

## Randomly sample cases to create independent training and test data
np.random.seed(9988)
indx1 = range(x_test.shape[0])
indx1 = ms.train_test_split(indx1, test_size = 0.5)
x_test1 = x_test[indx1[0],:]
y_test1 = np.ravel(y_test[indx1[0]])
x_test2 = x_test[indx1[1],:]
y_test2 = np.ravel(y_test[indx1[1]])

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (25269, 4)
# (25269,)
# (16846, 4)
# (16846,)

# %%
print(x_test1.shape)
print(y_test1.shape)
print(x_test2.shape)
print(y_test2.shape)
# Out:
# (8423, 4)
# (8423,)
# (8423, 4)
# (8423,)

# %%
df1.shape
# Out:
# (42115, 4)

# %%
rf = RandomForestRegressor(n_estimators=600, max_depth=15, max_features='auto',
                            min_samples_leaf=1, min_samples_split=2, random_state=0)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=15,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
xg_dt = xgb.XGBRegressor(boosting_type='gbtree', learning_rate=0.01, n_estimators=4000, max_depth=15, base_score=0.7)
eval_set = [(x_test1, y_test1)]
xg_dt.fit(x_train, y_train, eval_set=eval_set, early_stopping_rounds=200)
# Out:
# [0]	validation_0-rmse:87.43506
# Will train until validation_0-rmse hasn't improved in 200 rounds.
# [1]	validation_0-rmse:86.56695
# [2]	validation_0-rmse:85.70761
# [3]	validation_0-rmse:84.85694
# [4]	validation_0-rmse:84.01472
# [5]	validation_0-rmse:83.18111
# [6]	validation_0-rmse:82.35602
# [7]	validation_0-rmse:81.53895
# [8]	validation_0-rmse:80.72997
# [9]	validation_0-rmse:79.92956
# [10]	validation_0-rmse:79.13648
# [11]	validation_0-rmse:78.35200
# [12]	validation_0-rmse:77.57505
# [13]	validation_0-rmse:76.80581
# [14]	validation_0-rmse:76.04437
# [15]	validation_0-rmse:75.29067
# [16]	validation_0-rmse:74.54450
# [17]	validation_0-rmse:73.80593
# [18]	validation_0-rmse:73.07496
# [19]	validation_0-rmse:72.35126
# [20]	validation_0-rmse:71.63483
# [21]	validation_0-rmse:70.92567
# [22]	validation_0-rmse:70.22371
# [23]	validation_0-rmse:69.52856
# [24]	validation_0-rmse:68.84058
# [25]	validation_0-rmse:68.15916
# [26]	validation_0-rmse:67.48497
# [27]	validation_0-rmse:66.81770
# [28]	validation_0-rmse:66.15694
# [29]	validation_0-rmse:65.50269
# [30]	validation_0-rmse:64.85497
# [31]	validation_0-rmse:64.21352
# [32]	validation_0-rmse:63.57871
# [33]	validation_0-rmse:62.95060
# [34]	validation_0-rmse:62.32889
# [35]	validation_0-rmse:61.71322
# [36]	validation_0-rmse:61.10360
# [37]	validation_0-rmse:60.50007
# [38]	validation_0-rmse:59.90316
sample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#        gamma=0, gpu_id=-1, importance_type='gain',
#        interaction_constraints=None, learning_rate=0.01, max_delta_step=0,
#        max_depth=15, min_child_weight=1, missing=nan,
#        monotone_constraints=None, n_estimators=4000, n_jobs=0,
#        num_parallel_tree=1, objective='reg:squarederror', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#        tree_method=None, validate_parameters=False, verbosity=None)

# %%
pred_xg = xg_dt.predict(x_test2)
print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(pred_xg, y_test2) ** 0.5}')
print(f'The R2_score of DT values predicted on the validation data is {r2_score(pred_xg, y_test2) * 100}')

pred_rf = rf.predict(x_test2)
print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(pred_rf, y_test2) ** 0.5}')
print(f'The R2_score of DT values predicted on the validation data is {r2_score(pred_rf, y_test2) * 100}')
# Out:
# The RMSE of DT values predicted on the validation data is 4.592998466890794
# The R2_score of DT values predicted on the validation data is 96.2325377427777
# The RMSE of DT values predicted on the validation data is 4.635598298342829
# The R2_score of DT values predicted on the validation data is 96.14901364490852

# %%
test = pd.read_csv('edited.csv')
test = test.dropna()

dt = np.array(test['DT'])
test = test.drop(['DT', 'DEPTH'], axis=1)
test = np.array(test)

# %%
test = pd.read_csv('edited.csv')
test = test.dropna()
log_plot(test)

# %%
test.describe()
# Out:
#                  DT            GR          NPHI          RHOB            RT  \
# count  11464.000000  11464.000000  11464.000000  11464.000000  11464.000000
# mean      77.733619     32.902956      0.165742      2.468319      1.016314
# std       15.549873     51.034425      0.099682      0.153289      1.104634
# min       53.165000      0.852000      0.010000      2.033000     -2.273026
# 25%       66.184000      8.589250      0.093000      2.337000      0.600483
# 50%       71.579000     19.713500      0.130000      2.529000      1.125254
# 75%       87.674750     38.340000      0.223000      2.581000      1.604074
# max      126.827000   1124.403000      0.559000      3.025000     11.039569
#
#               DEPTH
# count  11464.000000
# mean    3150.150000
# std      330.951608
# min     2577.000000
# 25%     2863.575000
# 50%     3150.150000
# 75%     3436.725000
# max     3723.300000

# %%
predictions_xg = xg_dt.predict(test)
predictions_rf = rf.predict(test)

# %%
test = pd.read_csv('edited.csv')
test = test.dropna()
dt = np.array(test['DT'])
test['DT'] = predictions_xg
log_plot(test)

# %%
test.describe()
# Out:
#                  DT            GR          NPHI          RHOB            RT  \
# count  11464.000000  11464.000000  11464.000000  11464.000000  11464.000000
# mean      77.262192     32.902956      0.165742      2.468319      1.016314
# std       14.448483     51.034425      0.099682      0.153289      1.104634
# min       53.240585      0.852000      0.010000      2.033000     -2.273026
# 25%       66.776518      8.589250      0.093000      2.337000      0.600483
# 50%       71.173679     19.713500      0.130000      2.529000      1.125254
# 75%       87.376238     38.340000      0.223000      2.581000      1.604074
# max      122.125168   1124.403000      0.559000      3.025000     11.039569
#
#               DEPTH
# count  11464.000000
# mean    3150.150000
# std      330.951608
# min     2577.000000
# 25%     2863.575000
# 50%     3150.150000
# 75%     3436.725000
# max     3723.300000

# %%
test['DT'] = predictions_xg
log_plot(test)

# %%
print(dt[0:20])
print('')
print(predictions_xg[0:20])
print('')
print(predictions_rf[0:20])
# Out:
# [109.385 110.132 110.843 111.01  110.797 110.053 108.81  107.26  106.38
#  105.081 103.452 103.758 103.968 104.077 105.942 107.291 107.911 108.167
#  108.126 107.677]
#
# [107.63234  110.10261  111.020874 109.458954 104.639114 109.03981
#  108.204735 106.424286  97.85777  101.61265  100.8346    90.0677
#   80.523285  93.075424 103.73467  107.518906 107.22577  102.442215
#  108.2895   108.27479 ]
#
# [106.59225777 107.58142094 107.81984    106.94476686 105.01852978
#  107.11496818 105.031869   102.93534089  99.97326485  98.076273
#   97.73045332  90.9218237   89.92750089  95.03958807 101.01026207
#  107.38215517 105.83172369 106.08117715 109.20287895 110.48311797]

# %%
print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(predictions_xg, dt) ** 0.5}')
print(f'The R2_Score of DT values predicted on the validation data is {r2_score(predictions_xg, dt) * 100}')

print(f'The RMSE of DT values predicted on the validation data is {mean_squared_error(predictions_rf, dt) ** 0.5}')
print(f'The R2_Score of DT values predicted on the validation data is {r2_score(predictions_rf, dt) * 100}')
# Out:
# The RMSE of DT values predicted on the validation data is 4.978193115294974
# The R2_Score of DT values predicted on the validation data is 88.1276576028345
# The RMSE of DT values predicted on the validation data is 4.789401761120134
# The R2_Score of DT values predicted on the validation data is 88.92202687018823

# %%
test.describe()
# Out:
#                  DT            GR          NPHI          RHOB            RT  \
# count  11464.000000  11464.000000  11464.000000  11464.000000  11464.000000
# mean      77.262192     32.902956      0.165742      2.468319      1.016314
# std       14.448483     51.034425      0.099682      0.153289      1.104634
# min       53.240585      0.852000      0.010000      2.033000     -2.273026
# 25%       66.776518      8.589250      0.093000      2.337000      0.600483
# 50%       71.173679     19.713500      0.130000      2.529000      1.125254
# 75%       87.376238     38.340000      0.223000      2.581000      1.604074
# max      122.125168   1124.403000      0.559000      3.025000     11.039569
#
#               DEPTH
# count  11464.000000
# mean    3150.150000
# std      330.951608
# min     2577.000000
# 25%     2863.575000
# 50%     3150.150000
# 75%     3436.725000
# max     3723.300000

# %%
rf.feature_importances_
# Out:
# array([0.06716792, 0.73975363, 0.17689994, 0.01617851])

# %%
xg_dt.feature_importances_
# Out:
# array([0.03590178, 0.76666087, 0.1871322 , 0.01030516], dtype=float32)

# %%
edited = pd.read_csv('11B.csv')

edited = edited.drop(['DEPTH'], axis=1)
edited = np.array(edited)

rf_11b = rf.predict(edited)

edited = pd.read_csv('11B.csv')
edited['DT'] = rf_11b

edited['RT'] = np.log(edited['RT'])
log_plot1(edited)

# %%
edited.to_csv('final_11B.csv', index=False)

# %%
edited = pd.read_csv('15D.csv')

edited = edited.drop(['DEPTH'], axis=1)
edited = np.array(edited)

rf_15D = rf.predict(edited)

edited = pd.read_csv('15D.csv')
edited['DT'] = rf_15D

edited['RT'] = np.log(edited['RT'])
log_plot1(edited)

# %%
scores = cross_val_score(rf, x_train, y_train, cv=5)

# %%
print(scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# [0.96006535 0.96346873 0.96261474 0.96000708 0.95771592]
# Accuracy: 0.96 (+/- 0.00)
